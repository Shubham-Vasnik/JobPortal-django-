# %%
import pandas as pd

# %%
df=pd.read_csv('output.csv')

# %%
df.columns
# Out:
# Index(['availability', 'category', 'coursePictureUrl', 'credits', 'endDate',
#        'enrolled', 'enrollmentEndDate', 'estimatedWorkload', 'examDate',
#        'explorerInstructorName', 'explorerSummary', 'featured', 'id',
#        'instructorInstitute', 'name', 'ncCode', 'nodeCode',
#        'openForRegistration', 'showInExplorer', 'startDate', 'title', 'url',
#        'weeks'],
#       dtype='object')

# %%
df.head(5)
# Out:
#             availability category  \
# 0  registration_required      NaN
# 1  registration_required      NaN
# 2  registration_required      NaN
# 3  registration_required      NaN
# 4  registration_required      NaN
#
#                                     coursePictureUrl credits  \
# 0  https://storage.googleapis.com/swayam-node2-pr...       4
# 1  https://storage.googleapis.com/swayam2-node/Ja...       1
# 2  https://storage.googleapis.com/swayam2-node/Ja...       1
# 3  https://storage.googleapis.com/swayam2-node/Ja...       1
# 4  https://storage.googleapis.com/swayam-node2-pr...       3
#
#                        endDate enrolled            enrollmentEndDate  \
# 0  2020-04-18T00:00:00.000000Z    False  2020-02-28T00:00:00.000000Z
# 1  2020-02-21T00:00:00.000000Z    False  2020-02-02T18:30:00.000000Z
# 2  2020-02-21T00:00:00.000000Z    False  2020-02-02T18:30:00.000000Z
# 3  2020-02-21T00:00:00.000000Z    False  2020-02-02T18:30:00.000000Z
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 23 columns):
# availability              600 non-null object
# category                  1 non-null object
# coursePictureUrl          595 non-null object
# credits                   574 non-null object
# endDate                   574 non-null object
# enrolled                  600 non-null object
# enrollmentEndDate         573 non-null object
# estimatedWorkload         0 non-null float64
# examDate                  508 non-null object
# explorerInstructorName    597 non-null object
# explorerSummary           21 non-null object
# featured                  600 non-null object
# id                        599 non-null object
# instructorInstitute       597 non-null object
# name                      600 non-null object
# ncCode                    600 non-null object
# nodeCode                  600 non-null object
# openForRegistration       600 non-null object
# ...

# %%
df.featured.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: featured, dtype: object
